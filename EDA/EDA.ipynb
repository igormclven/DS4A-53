020
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
predial_ = pd.concat([d_2000,d_2001,d_2003,d_2004,d_2005,d_2006,d_2007,d_2008,d_2009,d_2010,d_2011,d_2012,d_2013,d_2014,d_2015,d_2016,d_2017,d_2018,d_2019,d_2020],ignore_index=True,axis=0)
predial_['invoice'] = (predial_['vlr_tot_avaluo']*predial_['cc_tarifa'])/1000
sns.set(rc={'figure.figsize':(20,8)})
x = sns.lineplot(data = predial_.groupby(by=['year']).sum()[['invoice','vlr_tot_avaluo']].reset_index(), x='year', y='invoice')
plt.title("Total invoiced over years")
plt.setp(x,xticks=range(2000,2021))

# %%
predial_.groupby(by=['year']).sum()[['invoice','vlr_tot_avaluo']].reset_index()
# Out:
#     year       invoice  vlr_tot_avaluo
# 0   2000  4.938739e+09    512056690300
# 1   2001  4.999981e+09    520538823471
# 2   2003  6.016597e+09    607046715184
# 3   2004  6.283928e+09    619977323173
# 4   2005  7.817844e+09    789028451147
# 5   2006  7.652235e+09    828745065938
# 6   2007  7.318897e+09    862907202601
# 7   2008  7.501035e+09    888672412832
# 8   2009  3.819863e+10   1193930192909
# 9   2010  3.897012e+10   1223194676973
# 10  2011  4.123724e+10   1243578445796
# 11  2012  4.750405e+10   1614549780699
# 12  2013  5.013437e+10   1674236462811
# 13  2014  5.189044e+10   1710378894802
# 14  2015  5.648110e+10   1799055195646
# 15  2016  5.654174e+10   1925492844729
# 16  2017  1.074809e+11   2953336887516
# 17  2018  1.388002e+11   3165259886619
# 18  2019  9.908505e+10   3558872811313
# 19  2020  1.129028e+11   3657723427777

# %%
predial_.head()
# Out:
#    consecutivo predial  corregimiento  barrio  ...  total_owners  year    invoice
# 0                 2972              1       1  ...             1  2000  26699.063
# 1                12157              1      10  ...             1  2000  16357.185
# 2                12159              1      10  ...             2  2000  24994.218
# 3                12160              1      10  ...             1  2000  55903.337
# 4                12161              1      10  ...             2  2000  42010.938
#
# [5 rows x 20 columns]

# %%
predial_.to_csv('predial.csv')

# %%
from google.colab import files
files.download('predial.csv')

# %%
sns.heatmap(predial_.corr(),cmap="YlGnBu")

# %%
import matplotlib.pyplot as plt
m = predial_.groupby(by = "destinacion").mean()[["invoice"]].reset_index()
m
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(m['destinacion'], m['invoice'])
plt.xlabel('destinacion')  
plt.ylabel('promedio de invoice')
# Out:
# Text(0, 0.5, 'promedio de invoice')

# %%
sns.barplot(x = 'destinacion', y='invoice', data = m)

# %%
x = predial_.groupby(by = "estrato").mean()[["area_const"]].reset_index()
x
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(x['estrato'], x['area_const'])
plt.xlabel('estarto')  
plt.ylabel('promedio de area contruida')
# Out:
# Text(0, 0.5, 'promedio de area contruida')

# %%
sns.set_theme(style="whitegrid")
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=predial_,
    x="destinacion", y="invoice")
